# %% [markdown]
# # 1. Set up project in GCP
# Using console.cloud.google.com, I set up a project called grav-waves. This project was automatically assigned a suffix (358320) by Google (most probably because this project exists somewhere else already on GCP).
#
# # 2. Generate owner JSON key
# Next, I created a service account and generated a [JSON key with owner access to that service account](https://cloud.google.com/iam/docs/creating-managing-service-accounts).
#
# # 3. Upload key
# I uploaded data and the JSON key from step 2 to the MNtrafficER folder containing this and the other scripts.
#
# Next, I ran the code below to stand-up the database.

# %%
from google.cloud import bigquery
from google.oauth2 import service_account
import pandas as pd
import numpy as np
import datetime

# %%
# Mount drive - needed for GBQ creds
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
root_path = '/content/drive/MyDrive/GitHub'

# %%
credentials = service_account.Credentials.from_service_account_file(
    f'{root_path}/MNtrafficER/key/mn-dps-incidents-03da8ed88c61.json', scopes=["https://www.googleapis.com/auth/cloud-platform"],
)

client = bigquery.Client(credentials=credentials, project=credentials.project_id,)

# %% [markdown]
# # 4. Import DPS extracts & clean

# %%
path_prefix = '/content/drive/MyDrive/GitHub/MNtrafficER/data'

incidents = pd.read_csv(f'{path_prefix}/incidents_2023-02-27 22_13_03.csv')
vehicles = pd.read_csv(f'{path_prefix}/vehicles_2023-02-27 22_13_03.csv')

# Clean up date fields and drop extraneous columns
incidents['incident_date_time'] = pd.to_datetime(incidents['date_time'], infer_datetime_format = True)
incidents['last_updated'] = pd.to_datetime(incidents['last_updated'], infer_datetime_format = True)
incidents = incidents.drop(columns = ['date_time'])

# %%
incidents.head()
# Out:
#                                           addtl_info  \
# 0  This fatal crash involved an unbelted/unrestra...
# 1                      Information believed complete
# 2                      Information believed complete
# 3                      Information believed complete
# 4                      Information believed complete
#
#                                    contact  \
# 0  MSP PIO Lt. Gordon Shank (651) 343-4680
# 1         Sgt. Jesse Grabow (218) 639-3168
# 2  MSP PIO Lt. Gordon Shank (651) 343-4680
# 3  MSP PIO Lt. Gordon Shank (651) 343-4680
# 4    Sgt. Troy Christianson (507) 923-2050
#
#                                          description            district  \
# 0  A Nissan Maxima was at a high rate of speed No...     2400 East Metro
# 1  Semi was eastbound on I-94 near milepost 65 wh...  2900 Detroit Lakes
# 2  A Chevrolet Impala was southbound on Highway 5...       3100 Virginia
# 3  The Ford Fusion was southbound in the northbou...     2400 East Metro
# 4  The Chevrolet truck was northbound on US Hwy 7...       2300 Marshall
#
#         icr incident_type        last_updated  \
# 0  23401089         Fatal 2023-02-11 05:51:00
# 1  23900275        Injury 2023-02-13 11:18:00
# 2  23310194        Injury 2023-02-12 01:52:00
# 3  23401120         Fatal 2023-02-12 15:27:00
# 4  23300420        Injury 2023-02-12 16:13:00
#
#                                             location  \
# 0  Northbound Highway 61 North of Lower Afton Rd,...
# 1        EB I-94 MP64, TUMULI TWP, Otter Tail County
# 2  Hwy 53 just north of Willow River Road , LEIDI...
# 3  Northbound US Highway 61 and Jamaica Avenue , ...
# 4  US Hwy 75 at 211th St in Pipestone county, ALT...
#
#                                     outside_agencies road_condition  \
# 0     Ramsey County SO, St Paul PD, Prescott PD (WI)            Dry
# 1       Otter Tail County and Dalton Fire Department            Dry
# 2          Orr Fire, Cook Ambulance, St Louis County            Dry
# 3  Cottage Grove PD, Cottage Grove Fire and EMS, ...            Dry
# 4  Pipestone CSO, Lake Benton FD, Pipestone Amb, ...            Dry
#
#    incident_date_time
# 0 2023-02-10 23:08:00
# 1 2023-02-11 15:50:00
# 2 2023-02-11 23:03:00
# 3 2023-02-12 08:13:00
# 4 2023-02-12 13:29:00

# %%
vehicles.head()
# Out:
#    gender person_type  age airbag_deployed alcohol_involved  \
# 0     NaN      driver  NaN             Yes              NaN
# 1    male   passenger   17             Yes          Unknown
# 2    male   passenger   17             Yes              Yes
# 3    male   passenger   17             Yes          Unknown
# 4  female      driver   66              No               No
#
#              health_care_facility          helmet           injury_type  \
# 0                Regions Hospital  Not Applicable                   NaN
# 1  Ramsey County Medical Examiner  Not Applicable                 Fatal
# 2                Regions Hospital  Not Applicable  Non-life Threatening
# 3  Ramsey County Medical Examiner  Not Applicable                 Fatal
# 4           Fergus Falls Hospital  Not Applicable  Non-life Threatening
#
#             location                     name seat_belt  \
# 0                NaN             Male Age: 16       Yes
# 1  Prescott, WI, USA        Cadence Lee Allen        No
# 2  Prescott, WI, USA  Bryndan Anthony Hartman       Yes
# 3  Prescott, WI, USA     Aiden Patrick Nelson        No
# 4                NaN           Susan Recknell       Yes
#
#                   vehicle  incident_case_record
# 0      2008 Nissan Maxima              23401089
# 1      2008 Nissan Maxima              23401089
# 2      2008 Nissan Maxima              23401089
# 3      2008 Nissan Maxima              23401089
# 4  2022 Freightliner Semi              23900275

# %% [markdown]
# # 5. Push dataframes to GCP
# Create a dataset called dps within the project (mn-dps-incidents). Upload the newly cleaned dataframe to the mn-dps-incidents.dps.incidents table. Both the dataset and table are persistent, so this code only needs to be run once.
#
# For help specifying the schema, see [these instructions](https://cloud.google.com/bigquery/docs/schemas).

# %%
# Create DPS dataset
dps = bigquery.Dataset('mn-dps-incidents.dps')
dps.location = 'US'
dps = client.create_dataset(dps)

# %%
job_config = bigquery.LoadJobConfig(
    autodetect = True,
    source_format = bigquery.SourceFormat.CSV)

# %%
job = client.load_table_from_dataframe(incidents, 'mn-dps-incidents.dps.incidents', job_config = job_config)

# %%
job = client.load_table_from_dataframe(vehicles, 'mn-dps-incidents.dps.vehicles', job_config = job_config)

# %% [markdown]
# # 6. Test load

# %%
metro_q = '''SELECT *
FROM dps.incidents
WHERE district = '2400 East Metro';'''

metro_df = client.query(metro_q).to_dataframe()

# %%
metro_df
# Out:
#                                           addtl_info  \
# 0  This fatal crash involved an unbelted/unrestra...
# 1                      Information believed complete
# 2                      Information believed complete
# 3                      Information believed complete
#
#                                    contact  \
# 0  MSP PIO Lt. Gordon Shank (651) 343-4680
# 1  MSP PIO Lt. Gordon Shank (651) 343-4680
# 2  MSP PIO Lt. Gordon Shank (651) 343-4680
# 3  MSP PIO Lt. Gordon Shank (651) 343-4680
#
#                                          description         district  \
# 0  A Nissan Maxima was at a high rate of speed No...  2400 East Metro
# 1  The Ford Fusion was southbound in the northbou...  2400 East Metro
# 2  The Porche Panamera was traveling at a high ra...  2400 East Metro
# 3  Nissan Rogue and Buick Lacrosse were traveling...  2400 East Metro
#
#         icr incident_type        last_updated  \
# 0  23401089         Fatal 2023-02-11 05:51:00
# 1  23401120         Fatal 2023-02-12 15:27:00
# 2  23401299        Injury 2023-02-20 02:23:00
# 3  23401409         Fatal 2023-02-27 14:35:00
#
#                                             location  \
# 0  Northbound Highway 61 North of Lower Afton Rd,...
# 1  Northbound US Highway 61 and Jamaica Avenue , ...
# 2  North Bound Cleveland Ave to West Bound Hwy 36...
# 3  Northbound Highway 77 over I-35E, EAGAN, Dakot...
#
#                                     outside_agencies road_condition  \
# 0     Ramsey County SO, St Paul PD, Prescott PD (WI)            Dry
# 1  Cottage Grove PD, Cottage Grove Fire and EMS, ...            Dry
# 2  Ramsey County Sheriff, Roseville Police Depart...            Dry
# 3  Dakota County Sheriffs, Eagan Police, Eagan Fi...       Snow/Ice
#
#    incident_date_time
# 0 2023-02-10 23:08:00
# 1 2023-02-12 08:13:00
# 2 2023-02-19 23:51:00
# 3 2023-02-22 08:39:00
